# %% [markdown]
# # Exercícios

# %% [markdown]
# ### Aluno: Marcelo Ortiz de Santana - 334559

# %% [markdown]
# #### Utilizando o arquivo Pokemon.csv, responda as questões abaixo:

# %% [markdown]
# ### 1) Leia o arquivo usando pandas, imprima as 10 primeiras linhas

# %%
# resposta 1
import pandas as pd

df = pd.read_csv('./Pokemon.csv', index_col=0)
df.head(10)
# Out:
#                         Name Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                  Bulbasaur  Grass  Poison    318  45      49       49
# 2                    Ivysaur  Grass  Poison    405  60      62       63
# 3                   Venusaur  Grass  Poison    525  80      82       83
# 3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                 Charmander   Fire     NaN    309  39      52       43
# 5                 Charmeleon   Fire     NaN    405  58      64       58
# 6                  Charizard   Fire  Flying    534  78      84       78
# 6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 1       65       65     45           1      False
# 2       80       80     60           1      False
# ...

# %% [markdown]
# ### 2) Altere o nome das colunas passando todas as letras para maiúscula. Substitua o "." por ""

# %%
# resposta 2
columns = [col.upper().replace('.', '') for col in df.columns]
df.columns = columns
print(df)
# Out:
#                           NAME    TYPE 1  TYPE 2  TOTAL   HP  ATTACK  DEFENSE  \
# #
# 1                    Bulbasaur     Grass  Poison    318   45      49       49
# 2                      Ivysaur     Grass  Poison    405   60      62       63
# 3                     Venusaur     Grass  Poison    525   80      82       83
# 3        VenusaurMega Venusaur     Grass  Poison    625   80     100      123
# 4                   Charmander      Fire     NaN    309   39      52       43
# 5                   Charmeleon      Fire     NaN    405   58      64       58
# 6                    Charizard      Fire  Flying    534   78      84       78
# 6    CharizardMega Charizard X      Fire  Dragon    634   78     130      111
# 6    CharizardMega Charizard Y      Fire  Flying    634   78     104       78
# 7                     Squirtle     Water     NaN    314   44      48       65
# 8                    Wartortle     Water     NaN    405   59      63       80
# ...

# %% [markdown]
# ### 3) Imprima apenas os pokemons legendários

# %%
# resposta 3
print(df[df.LEGENDARY])
# Out:
#                          NAME    TYPE 1    TYPE 2  TOTAL   HP  ATTACK  \
# #
# 144                  Articuno       Ice    Flying    580   90      85
# 145                    Zapdos  Electric    Flying    580   90      90
# 146                   Moltres      Fire    Flying    580   90     100
# 150                    Mewtwo   Psychic       NaN    680  106     110
# 150       MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 150       MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 243                    Raikou  Electric       NaN    580   90      85
# 244                     Entei      Fire       NaN    580  115     115
# 245                   Suicune     Water       NaN    580  100      75
# 249                     Lugia   Psychic    Flying    680  106      90
# 250                     Ho-oh      Fire    Flying    680  106     130
# 377                  Regirock      Rock       NaN    580   80     100
# ...

# %% [markdown]
# ### 4) Verifique os valores faltantes existentes no dataset

# %%
# resposta 4
print(df[df.isnull()])
# Out:
#     NAME TYPE 1 TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP ATK  SP DEF  SPEED  \
# #
# 1    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 2    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 3    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 3    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 4    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 5    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 6    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 6    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 6    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 7    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 8    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# 9    NaN    NaN    NaN    NaN NaN     NaN      NaN     NaN     NaN    NaN
# ...

# %% [markdown]
# ### 5) Preencha os valores faltantes da coluna TYPE 2 com os valores correspondentes da coluna TYPE 1

# %%
# resposta 5
df['TYPE 2'].fillna(df['TYPE 1'])
df
# Out:
#                           NAME    TYPE 1  TYPE 2  TOTAL   HP  ATTACK  DEFENSE  \
# #
# 1                    Bulbasaur     Grass  Poison    318   45      49       49
# 2                      Ivysaur     Grass  Poison    405   60      62       63
# 3                     Venusaur     Grass  Poison    525   80      82       83
# 3        VenusaurMega Venusaur     Grass  Poison    625   80     100      123
# 4                   Charmander      Fire     NaN    309   39      52       43
# 5                   Charmeleon      Fire     NaN    405   58      64       58
# 6                    Charizard      Fire  Flying    534   78      84       78
# 6    CharizardMega Charizard X      Fire  Dragon    634   78     130      111
# 6    CharizardMega Charizard Y      Fire  Flying    634   78     104       78
# 7                     Squirtle     Water     NaN    314   44      48       65
# 8                    Wartortle     Water     NaN    405   59      63       80
# ...

# %% [markdown]
# ### 6) Agrupe os pokemons por TYPE 1, ordene pela quantidade em ordem decrescente

# %%
# resposta 6
x = df[['NAME', 'TYPE 1']]
x = x.groupby(['TYPE 1'], as_index=False).count()
x.rename(columns={'NAME': 'COUNT'}, inplace=True)
x.sort_values(by='COUNT', ascending=False)
# Out:
#       TYPE 1  COUNT
# 17     Water    112
# 12    Normal     98
# 9      Grass     70
# 0        Bug     69
# 14   Psychic     57
# 6       Fire     52
# 3   Electric     44
# 15      Rock     44
# 8      Ghost     32
# 10    Ground     32
# 2     Dragon     32
# 1       Dark     31
# 13    Poison     28
# 5   Fighting     27
# 16     Steel     27
# 11       Ice     24
# 4      Fairy     17
# 7     Flying      4
