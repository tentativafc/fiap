# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# # Dados Trabalho

# %%
dados_trabalho_2005_df = pd.read_csv('dados_trabalho_2005.csv', sep=';')
dados_trabalho_2005_df.head(100)
# Out:
#                             Classes  Total_10_anos  Homens_10_anos  \
# 0            Até 1/2 salário mínimo          11989            4047
# 1    Mais de 1/2 a 1 salário mínimo          26297           12381
# 2    Mais de 1 a 2 salários mínimos          29704           16637
# 3    Mais de 2 a 3 salários mínimos          11179            7104
# 4    Mais de 3 a 5 salários mínimos          10476            6734
# 5   Mais de 5 a 10 salários mínimos           6837            4385
# 6  Mais de 10 a 20 salários mínimos           2586            1735
# 7       Mais de 20 salários mínimos           1025             800
# 8                Sem rendimento (2)          51633           19323
# 9                    Sem declaração           1189             733
#
#    Mulheres_10_anos  Total_media_10_anos  Homens_media_10_anos  \
# 0              7942                 83.0                  90.0
# 1             13915                277.0                 274.0
# 2             13068                464.0                 469.0
# 3              4075                763.0                 764.0
# 4              3743               1191.0                1193.0
# 5              2452               2181.0                2197.0
# 6               851               4350.0                4373.0
# 7               225              10530.0               10718.0
# 8             32310                  NaN                   NaN
# 9               456                  NaN                   NaN
#
#    Mulheres_media_10_anos
# 0                    80.0
# 1                   279.0
# 2                   457.0
# 3                   760.0
# 4                  1188.0
# 5                  2152.0
# 6                  4303.0
# 7                  9858.0
# 8                     NaN
# 9                     NaN

# %%
dados_trabalho_2005_df.fillna(0, inplace=True)
dados_trabalho_2005_df
# Out:
#                             Classes  Total_10_anos  Homens_10_anos  \
# 0            Até 1/2 salário mínimo          11989            4047
# 1    Mais de 1/2 a 1 salário mínimo          26297           12381
# 2    Mais de 1 a 2 salários mínimos          29704           16637
# 3    Mais de 2 a 3 salários mínimos          11179            7104
# 4    Mais de 3 a 5 salários mínimos          10476            6734
# 5   Mais de 5 a 10 salários mínimos           6837            4385
# 6  Mais de 10 a 20 salários mínimos           2586            1735
# 7       Mais de 20 salários mínimos           1025             800
# 8                Sem rendimento (2)          51633           19323
# 9                    Sem declaração           1189             733
#
#    Mulheres_10_anos  Total_media_10_anos  Homens_media_10_anos  \
# 0              7942                 83.0                  90.0
# 1             13915                277.0                 274.0
# 2             13068                464.0                 469.0
# 3              4075                763.0                 764.0
# 4              3743               1191.0                1193.0
# 5              2452               2181.0                2197.0
# 6               851               4350.0                4373.0
# 7               225              10530.0               10718.0
# 8             32310                  0.0                   0.0
# 9               456                  0.0                   0.0
#
#    Mulheres_media_10_anos
# 0                    80.0
# 1                   279.0
# 2                   457.0
# 3                   760.0
# 4                  1188.0
# 5                  2152.0
# 6                  4303.0
# 7                  9858.0
# 8                     0.0
# 9                     0.0

# %%
dados_trabalho_2015_df = pd.read_csv('dados_trabalho_2015.csv', sep=';')
dados_trabalho_2015_df.head(11)
# Out:
#                             Classes  Total_10_anos  Homens_10_anos  \
# 0            Até 1/2 salário mínimo          12047            3109
# 1    Mais de 1/2 a 1 salário mínimo          31671           14202
# 2    Mais de 1 a 2 salários mínimos          42692           22549
# 3    Mais de 2 a 3 salários mínimos          15105            9537
# 4    Mais de 3 a 5 salários mínimos          10797            6789
# 5   Mais de 5 a 10 salários mínimos           6956            4319
# 6  Mais de 10 a 20 salários mínimos           2407            1607
# 7       Mais de 20 salários mínimos            708             526
# 8                Sem rendimento (2)          37472           13640
# 9                    Sem declaração           1937            1108
#
#    Mulheres_10_anos  Total_media_10_anos  Homens_media_10_anos  \
# 0              8938                199.0                 223.0
# 1             17468                718.0                 715.0
# 2             20143               1152.0                1166.0
# 3              5568               1923.0                1924.0
# 4              4009               2950.0                2948.0
# 5              2638               5162.0                5172.0
# 6               800              10479.0               10532.0
# 7               182              24477.0               24641.0
# 8             23831                  NaN                   NaN
# 9               829                  NaN                   NaN
#
#    Mulheres_media_10_anos
# 0                   191.0
# 1                   722.0
# 2                  1136.0
# 3                  1922.0
# 4                  2954.0
# 5                  5145.0
# 6                 10371.0
# 7                 24001.0
# 8                     NaN
# 9                     NaN

# %%
dados_trabalho_2015_df.fillna(0, inplace=True)
dados_trabalho_2015_df
# Out:
#                             Classes  Total_10_anos  Homens_10_anos  \
# 0            Até 1/2 salário mínimo          12047            3109
# 1    Mais de 1/2 a 1 salário mínimo          31671           14202
# 2    Mais de 1 a 2 salários mínimos          42692           22549
# 3    Mais de 2 a 3 salários mínimos          15105            9537
# 4    Mais de 3 a 5 salários mínimos          10797            6789
# 5   Mais de 5 a 10 salários mínimos           6956            4319
# 6  Mais de 10 a 20 salários mínimos           2407            1607
# 7       Mais de 20 salários mínimos            708             526
# 8                Sem rendimento (2)          37472           13640
# 9                    Sem declaração           1937            1108
#
#    Mulheres_10_anos  Total_media_10_anos  Homens_media_10_anos  \
# 0              8938                199.0                 223.0
# 1             17468                718.0                 715.0
# 2             20143               1152.0                1166.0
# 3              5568               1923.0                1924.0
# 4              4009               2950.0                2948.0
# 5              2638               5162.0                5172.0
# 6               800              10479.0               10532.0
# 7               182              24477.0               24641.0
# 8             23831                  0.0                   0.0
# 9               829                  0.0                   0.0
#
#    Mulheres_media_10_anos
# 0                   191.0
# 1                   722.0
# 2                  1136.0
# 3                  1922.0
# 4                  2954.0
# 5                  5145.0
# 6                 10371.0
# 7                 24001.0
# 8                     0.0
# 9                     0.0

# %% [markdown]
# ## Análise da distribuição das classes

# %% [markdown]
# ### 2005 vs 2015

# %%
cols1 = ['Homens_10_anos', 'Mulheres_10_anos']
cols2 = ['Homens_10_anos', 'Mulheres_10_anos']
desc_cols = ['entre Homens (10 anos)', 'entre Mulheres (10 anos)']
years = [2005, 2015]
dfs = [dados_trabalho_2005_df, dados_trabalho_2015_df]

num_cols = 2
fig, ax = plt.subplots(nrows=1, ncols=num_cols, figsize=(20, num_cols*5))

for index, col in enumerate(dfs):
   
    height1 = dfs[index][cols1[0]]
    height2 = dfs[index][cols1[1]]

    bars = dados_trabalho_2005_df['Classes']
    y_pos = np.arange(len(bars))
    plt.figure(figsize=(20, 7))
    
    p1 = ax[index].barh(y_pos, height1, alpha = 0.8, color = 'b')
    p2 = ax[index].barh(y_pos, height2, alpha = 0.3, color = 'r')
    
    ax[index].title.set_text(f"Distribuição dos salários mínimos em ({years[index]})")
    ax[index].set_yticks(y_pos)
    ax[index].set_yticklabels(bars)
    ax[index].set_xlabel('População impactada (1000)')
    ax[index].legend((p1[0], p2[0]), desc_cols)

# %% [markdown]
# #### Conclusão: houve uma significativa redução no número de pessoas sem rendimento, reduzindo a distância entre este número e a quantidade de pessoas que recebem entre 1 a 2 salários mínimos.
