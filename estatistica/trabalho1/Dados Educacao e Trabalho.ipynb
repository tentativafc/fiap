# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# # Dados de Educação

# %%
dados_educacao_2005_df = pd.read_csv('dados_educacao_2005.csv', sep=';')
dados_educacao_2005_df.head(100)
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0        5 e 6 anos   6725    3470      3256       5384        2771
# 1            7 anos   3367    1707      1660       2689        1372
# 2        8 e 9 anos   6927    3511      3416       5512        2799
# 3      10 a 14 anos  17216    8799      8416      13645        6931
# 4      15 a 19 anos  17754    8968      8786      14407        7183
# 5      20 a 24 anos  17338    8678      8660      14624        7225
# 6      25 a 29 anos  15483    7531      7952      13172        6328
# 7      30 a 39 anos  27049   12996     14053      22914       10871
# 8      40 a 49 anos  23384   11138     12246      19922        9304
# 9      50 a 59 anos  16416    7744      8671      13769        6371
# 10  60 anos ou mais  18214    7988     10226      15134        6370
# 11   Idade ignorada     62      36        26         55          30
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# ...

# %%
dados_educacao_2005_df = dados_educacao_2005_df[:-1] #drop lastline 
dados_educacao_2005_df
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0        5 e 6 anos   6725    3470      3256       5384        2771
# 1            7 anos   3367    1707      1660       2689        1372
# 2        8 e 9 anos   6927    3511      3416       5512        2799
# 3      10 a 14 anos  17216    8799      8416      13645        6931
# 4      15 a 19 anos  17754    8968      8786      14407        7183
# 5      20 a 24 anos  17338    8678      8660      14624        7225
# 6      25 a 29 anos  15483    7531      7952      13172        6328
# 7      30 a 39 anos  27049   12996     14053      22914       10871
# 8      40 a 49 anos  23384   11138     12246      19922        9304
# 9      50 a 59 anos  16416    7744      8671      13769        6371
# 10  60 anos ou mais  18214    7988     10226      15134        6370
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# 0           2614       1341         699           642
# ...

# %%
dados_educacao_2015_df = pd.read_csv('dados_educacao_2015.csv', sep=';')
dados_educacao_2015_df.head(100)
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0       5 ou 6 anos   5432    2759      2672       4493        2275
# 1            7 anos   2868    1471      1397       2340        1203
# 2       8 ou 9 anos   5962    3058      2904       4847        2485
# 3      10 a 14 anos  15864    8103      7761      12841        6537
# 4      15 a 19 anos  17479    8911      8568      14523        7304
# 5      20 a 24 anos  15591    7955      7636      13518        6835
# 6      25 a 29 anos  15276    7526      7749      13181        6477
# 7      30 a 39 anos  32039   15463     16576      27587       13154
# 8      40 a 49 anos  28144   13473     14670      24115       11352
# 9      50 a 59 anos  23891   11112     12779      20472        9325
# 10  60 anos ou mais  29374   12945     16429      24750       10530
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# 0           2217        939         484           455
# ...

# %% [markdown]
# ## Análise da distribuição das classes

# %% [markdown]
# ### Comparação entre os totais entre 2005 e 2015

# %%
desc_cols = ['2005', '2015']
height1 = dados_educacao_2005_df['Total']
height2 = dados_educacao_2015_df['Total']

bars = dados_educacao_2005_df['Classes']
y_pos = np.arange(len(bars))
plt.figure(figsize=(20, 10))
height = 0.4
plt.yticks(y_pos - height /2, bars)
p1 = plt.barh(y_pos, height1, height=height)
p2 = plt.barh(y_pos - height, height2, height=height)
plt.legend((p1[0], p2[0]), desc_cols)

plt.xlabel('Pessoas de 5 anos ou mais de idade (1000 pessoas)')
plt.title('Educação - Pessoas de 5 anos ou mais de idade (1000 pessoas)')
plt.show()

# %% [markdown]
# ## Comparativo entre alfabetizados

# %%
df_alfabetizados_2005_df = pd.read_csv('dados_educacao_alfabetizadas_2005.csv', sep=';')
df_alfabetizados_2005_df.head(100)
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0        5 e 6 anos   1789     888       901       1592         797
# 1            7 anos   2402    1179      1222       2049        1018
# 2        8 e 9 anos   6025    2988      3038       5013        2508
# 3      10 a 14 anos  16636    8395      8241      13330        6712
# 4      15 a 19 anos  17345    8682      8663      14177        7027
# 5      20 a 24 anos  16742    8287      8455      14294        7016
# 6      25 a 29 anos  14597    6987      7610      12683        6035
# 7      30 a 39 anos  24958   11796     13162      21704       10197
# 8      40 a 49 anos  20866    9828     11038      18371        8551
# 9      50 a 59 anos  13581    6433      7148      11991        5617
# 10  60 anos ou mais  12553    5685      6868      11144        4896
# 11   Idade ignorada     52      30        22         45          24
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# ...

# %%
df_alfabetizados_2005_df = df_alfabetizados_2005_df[:-1] #drop lastline 
df_alfabetizados_2005_df
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0        5 e 6 anos   1789     888       901       1592         797
# 1            7 anos   2402    1179      1222       2049        1018
# 2        8 e 9 anos   6025    2988      3038       5013        2508
# 3      10 a 14 anos  16636    8395      8241      13330        6712
# 4      15 a 19 anos  17345    8682      8663      14177        7027
# 5      20 a 24 anos  16742    8287      8455      14294        7016
# 6      25 a 29 anos  14597    6987      7610      12683        6035
# 7      30 a 39 anos  24958   11796     13162      21704       10197
# 8      40 a 49 anos  20866    9828     11038      18371        8551
# 9      50 a 59 anos  13581    6433      7148      11991        5617
# 10  60 anos ou mais  12553    5685      6868      11144        4896
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# 0            795        197          91           106
# ...

# %%
df_alfabetizados_2015_df = pd.read_csv('dados_educacao_alfabetizadas_2015.csv', sep=';')
df_alfabetizados_2015_df.head(100)
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0       5 ou 6 anos   2123    1065      1058       1852         927
# 1            7 anos   2306    1163      1143       1952         997
# 2       8 ou 9 anos   5531    2801      2729       4585        2322
# 3      10 a 14 anos  15615    7940      7675      12675        6428
# 4      15 a 19 anos  17337    8814      8522      14431        7242
# 5      20 a 24 anos  15390    7815      7575      13392        6752
# 6      25 a 29 anos  14979    7341      7638      13011        6376
# 7      30 a 39 anos  30765   14673     16092      26895       12753
# 8      40 a 49 anos  26169   12322     13846      22985       10727
# 9      50 a 59 anos  21469    9889     11580      18993        8628
# 10  60 anos ou mais  22818   10127     12691      20262        8802
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# 0            925        272         139           133
# ...

# %%
desc_cols = ['2005', '2015']

df_alfabetizados_2005_df['Total_NORM'] = df_alfabetizados_2005_df['Total'] / dados_educacao_2005_df['Total'].sum()
df_alfabetizados_2015_df['Total_NORM'] = df_alfabetizados_2015_df['Total'] / dados_educacao_2015_df['Total'].sum()

height1 = df_alfabetizados_2005_df['Total_NORM']
height2 = df_alfabetizados_2015_df['Total_NORM']

bars = dados_educacao_2005_df['Classes']
y_pos = np.arange(len(bars))
plt.figure(figsize=(20, 10))
height = 0.4
plt.yticks(y_pos - height /2, bars)
p1 = plt.barh(y_pos, height1, height=height)
p2 = plt.barh(y_pos - height, height2, height=height)
plt.legend((p1[0], p2[0]), desc_cols)

plt.xlabel('Taxa de pessoas de 5 anos ou mais de idade alfabetizadas')
plt.title('Educação - Comparativo entre a taxa de pessoas alfabetizadas de 5 anos ou mais de idade entre 2005 e 2015')
plt.show()

# %% [markdown]
# #### Conclusão: Entre as idades de 7 a 29 anos, a taxa de pessoas alfabetizadas diminuiu, e entre 30 a 60 anos a taxa aumentou.

# %% [markdown]
# ## Comparativo entre alfabetizados na zona urbana e rural¶

# %%
desc_cols = ['2005', '2015']

df_alfabetizados_2005_df['Total_NORM'] = df_alfabetizados_2005_df['Total_URB'] / dados_educacao_2005_df['Total_URB'].sum()
df_alfabetizados_2015_df['Total_NORM'] = df_alfabetizados_2015_df['Total_URB'] / dados_educacao_2015_df['Total_URB'].sum()

height1 = df_alfabetizados_2005_df['Total_NORM']
height2 = df_alfabetizados_2015_df['Total_NORM']

bars = dados_educacao_2005_df['Classes']
y_pos = np.arange(len(bars))
plt.figure(figsize=(20, 10))
height = 0.4
plt.yticks(y_pos - height /2, bars)
p1 = plt.barh(y_pos, height1, height=height)
p2 = plt.barh(y_pos - height, height2, height=height)
plt.legend((p1[0], p2[0]), desc_cols)

plt.xlabel('Taxa de pessoas de 5 anos ou mais de idade alfabetizadas - Zona Urbana')
plt.title('Educação - Comparativo entre a taxa de pessoas alfabetizadas de 5 anos ou mais de idade entre 2005 e 2015 - Zona Urbana')
plt.show()

# %% [markdown]
# #### Conclusão: Obedece a mesma conclusão do total, entre as idades de 7 a 29 anos, a taxa de pessoas alfabetizadas diminuiu, e entre 30 a 60 anos a taxa aumentou.

# %%
desc_cols = ['2005', '2015']

df_alfabetizados_2005_df['Total_NORM'] = df_alfabetizados_2005_df['Total_RUR'] / dados_educacao_2005_df['Total_RUR'].sum()
df_alfabetizados_2015_df['Total_NORM'] = df_alfabetizados_2015_df['Total_RUR'] / dados_educacao_2015_df['Total_RUR'].sum()

height1 = df_alfabetizados_2005_df['Total_NORM']
height2 = df_alfabetizados_2015_df['Total_NORM']

bars = dados_educacao_2005_df['Classes']
y_pos = np.arange(len(bars))
plt.figure(figsize=(20, 10))
height = 0.4
plt.yticks(y_pos - height /2, bars)
p1 = plt.barh(y_pos, height1, height=height)
p2 = plt.barh(y_pos - height, height2, height=height)
plt.legend((p1[0], p2[0]), desc_cols)

plt.xlabel('Taxa de pessoas de 5 anos ou mais de idade alfabetizadas - Zona Rural')
plt.title('Educação - Comparativo entre a taxa de pessoas alfabetizadas de 5 anos ou mais de idade entre 2005 e 2015 - Zona Rural')
plt.show()

# %% [markdown]
# #### Conclusão: A taxa de 7 anos ficou na mesma taxa, de 8 a 24 anos diminuiu a taxa de alfabetizados e após 25 anos, houve melhora na taxa de alfabetização.

# %% [markdown]
# ## Comparativo entre não alfabetizados

# %%
df_nao_alfabetizados_2005_df = pd.read_csv('dados_educacao_nao_alfabetizadas_2005.csv', sep=';')
df_nao_alfabetizados_2005_df.head(100)
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0        5 e 6 anos   4937    2581      2355       3792        1973
# 1            7 anos    965     527       438        639         355
# 2        8 e 9 anos    902     524       378        499         292
# 3      10 a 14 anos    579     404       175        314         219
# 4      15 a 19 anos    407     285       123        228         154
# 5      20 a 24 anos    595     389       205        328         208
# 6      25 a 29 anos    886     544       342        489         293
# 7      30 a 39 anos   2089    1199       890       1209         673
# 8      40 a 49 anos   2518    1309      1209       1551         753
# 9      50 a 59 anos   2833    1311      1522       1776         754
# 10  60 anos ou mais   5658    2302      3356       3987        1473
# 11   Idade ignorada      9       5         4          8           4
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# ...

# %%
df_nao_alfabetizados_2005_df = df_nao_alfabetizados_2005_df[:-1] #drop lastline 
df_nao_alfabetizados_2005_df
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0        5 e 6 anos   4937    2581      2355       3792        1973
# 1            7 anos    965     527       438        639         355
# 2        8 e 9 anos    902     524       378        499         292
# 3      10 a 14 anos    579     404       175        314         219
# 4      15 a 19 anos    407     285       123        228         154
# 5      20 a 24 anos    595     389       205        328         208
# 6      25 a 29 anos    886     544       342        489         293
# 7      30 a 39 anos   2089    1199       890       1209         673
# 8      40 a 49 anos   2518    1309      1209       1551         753
# 9      50 a 59 anos   2833    1311      1522       1776         754
# 10  60 anos ou mais   5658    2302      3356       3987        1473
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# 0           1819       1144         608           536
# ...

# %%
df_nao_alfabetizados_2015_df = pd.read_csv('dados_educacao_nao_alfabetizadas_2015.csv', sep=';')
df_nao_alfabetizados_2015_df.head(100)
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0       5 ou 6 anos   3308    1694      1615       2641        1349
# 1            7 anos    562     308       254        387         206
# 2       8 ou 9 anos    431     257       174        262         163
# 3      10 a 14 anos    250     164        86        166         109
# 4      15 a 19 anos    142      97        46         92          63
# 5      20 a 24 anos    200     140        60        125          83
# 6      25 a 29 anos    296     185       112        170         100
# 7      30 a 39 anos   1274     790       484        692         401
# 8      40 a 49 anos   1975    1151       824       1130         625
# 9      50 a 59 anos   2422    1223      1199       1479         697
# 10  60 anos ou mais   6556    2818      3738       4488        1728
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# 0           1292        667         345           322
# ...

# %%
desc_cols = ['2005', '2015']

df_nao_alfabetizados_2005_df['Total_NORM'] = df_nao_alfabetizados_2005_df['Total'] / dados_educacao_2005_df['Total'].sum()
df_nao_alfabetizados_2015_df['Total_NORM'] = df_nao_alfabetizados_2015_df['Total'] / dados_educacao_2015_df['Total'].sum()

height1 = df_nao_alfabetizados_2005_df['Total_NORM']
height2 = df_nao_alfabetizados_2015_df['Total_NORM']

bars = dados_educacao_2005_df['Classes']
y_pos = np.arange(len(bars))
plt.figure(figsize=(20, 10))
height = 0.4
plt.yticks(y_pos - height /2, bars)
p1 = plt.barh(y_pos, height1, height=height)
p2 = plt.barh(y_pos - height, height2, height=height)
plt.legend((p1[0], p2[0]), desc_cols)

plt.xlabel('Taxa de pessoas de 5 anos ou mais de idade não alfabetizadas')
plt.title('Educação - Comparativo entre a taxa de pessoas não alfabetizadas de 5 anos ou mais de idade entre 2005 e 2015')
plt.show()

# %%
#### Conclusão: ra na taxa de alfabetização.

# %%
# Juncao dos dfs

df_alf_2005 = df_alfabetizados_2005_df.filter(['Classes', 'Total_NORM'], axis=1)
df_alf_2005
df_alf_2015 = df_alfabetizados_2015_df.filter(['Classes', 'Total_NORM'], axis=1)

# df_alf_2015

df_alf_2015['Total_NORM_20015'] = df_alf_2015['Total_NORM']
df_alf_2015

del(df_alf_2015['Total_NORM'])
df_alf_2005 = df_alf_2005.set_index('Classes')
df_alf_2015 = df_alf_2015.set_index('Classes')

# # df_alf_2015.set_index('Classes')

result_df = df_alf_2005.join(df_alf_2015, on='Classes')
print(df_alf_2005)
print(df_alf_2015)
print(result_df)
# # df.join(other.set_index('key'), on='key')


for ind in result_df.index:
    
#     df_filtered = df_grouped[df_grouped['Type 1'] == tp]  
    plt.plot(result_df['Total_NORM'], result_df['Total_NORM'], label=ind)

plt.legend()
    

# df_grouped = df.groupby(['Generation', 'Type 1'], as_index=False).count()

# types = df_grouped['Type 1'].unique()
# types.sort(axis=0)
# types

# plt.figure(figsize=(20,10))  

# for tp in types:
# #     df_filtered = df_grouped[df_grouped['Type 1'] == tp]  
#     plt.plot(df_filtered['Generation'], df_filtered['#'], label=tp)

# plt.legend()
# Out:
#                  Total_NORM
# Classes
# 5 e 6 anos         0.010531
# 7 anos             0.014140
# 8 e 9 anos         0.035468
# 10 a 14 anos       0.097932
# 15 a 19 anos       0.102106
# 20 a 24 anos       0.098556
# 25 a 29 anos       0.085929
# 30 a 39 anos       0.146922
# 40 a 49 anos       0.122833
# 50 a 59 anos       0.079948
# 60 anos ou mais    0.073896
#                  Total_NORM_20015
# Classes
# 5 ou 6 anos              0.011062
# 7 anos                   0.012015
# 8 ou 9 anos              0.028819
# 10 a 14 anos             0.081362
# 15 a 19 anos             0.090335
# 20 a 24 anos             0.080190
# 25 a 29 anos             0.078048
# 30 a 39 anos             0.160301
# 40 a 49 anos             0.136354
# 50 a 59 anos             0.111864
# 60 anos ou mais          0.118893
#                  Total_NORM  Total_NORM_20015
# Classes
# 5 e 6 anos         0.010531               NaN
# 7 anos             0.014140          0.012015
# ...

# %%
df_grouped = df.groupby(['Generation', 'Type 1'], as_index=False).count()

types = df_grouped['Type 1'].unique()
types.sort(axis=0)
types

plt.figure(figsize=(20,10))  

for tp in types:
    df_filtered = df_grouped[df_grouped['Type 1'] == tp]  
    plt.plot(df_filtered['Generation'], df_filtered['#'], label=tp)

plt.legend()

# %%
df_empregos_2005_df = pd.read_csv('dados_trabalho_2005.csv', sep=';')
df_empregos_2005_df.head(100)

df_empregos_2015_df = pd.read_csv('dados_trabalho_2015.csv', sep=';')
df_empregos_2015_df.head(100)


df_empregos_2005_df['Total_NORM'] = df_empregos_2005_df['Total_10_anos'] / df_empregos_2005_df['Total_10_anos'].sum()
df_empregos_2015_df['Total_NORM'] = df_empregos_2015_df['Total_10_anos'] / df_empregos_2015_df['Total_10_anos'].sum()

df_empregos_2015_df


height1 = df_empregos_2005_df['Total_NORM']
height2 = df_empregos_2015_df['Total_NORM']

bars = df_empregos_2005_df['Classes']
y_pos = np.arange(len(bars))
plt.figure(figsize=(20, 10))
height = 0.4
plt.yticks(y_pos - height /2, bars)
p1 = plt.barh(y_pos, height1, height=height)
p2 = plt.barh(y_pos - height, height2, height=height)
plt.legend((p1[0], p2[0]), desc_cols)

plt.xlabel('Distribução')
plt.title('Comparativo da distribuição entre os salários de pessoas com 10 anos ou mais entre 2005 e 2015')
plt.show()
